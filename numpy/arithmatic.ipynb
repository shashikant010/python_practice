# %%
import numpy as np

# %%
numbers = np.array([1,2,3,4,5,6])

# %%
newNumbers = numbers+3
newNumbers
# Out:
# array([4, 5, 6, 7, 8, 9])

# %%
numbers2=[3,4,5,6,5,3]

# %%
numbers3=numbers+numbers2
numbers3
# Out:
# array([ 4,  6,  8, 10, 10,  9])

# %%
numbersAfterMultiply = numbers3 *2
numbersAfterMultiply
# Out:
# array([ 8, 12, 16, 20, 20, 18])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
array1=np.array([1,2,3,4])

# %%
print("the minimum value in the array is : ",np.min(array1),"at",np.argmin(array1))
print("the maximum value in the array is : ",np.max(array1),"at",np.argmax(array1))
# Out:
# the minimum value in the array is :  1 at 0
# the maximum value in the array is :  4 at 3

# %%
array2 = np.array([[1,2,3,4],[5,6,7,8]])

# %%
print("the minimum value along row in array is : ",np.min(array2,axis=0))
print("the minimum value along column in array is : ",np.min(array2,axis=1))
# Out:
# the minimum value along row in array is :  [1 2 3 4]
# the minimum value along column in array is :  [1 5]

# %%
print("cumsum of array1 is : ", np.cumsum(array1))
# Out:
# cumsum of array1 is :  [ 1  3  6 10]

# %% [markdown]
# BROADCASTING RULES
# ADDITION
# no error
# ![image.png](attachment:image.png)
# this will give error
# ![image-2.png](attachment:image-2.png)
# this will not give error
# ![image-3.png](attachment:image-3.png)
