# %%
import numpy as np

# %%
array1=np.array([1,2,3,4,1,2,1,1,2,3,4,2,5,6,5,6,4])

# %%
np.random.shuffle(array1)
array1
# Out:
# array([1, 1, 2, 5, 6, 4, 2, 2, 3, 1, 2, 3, 6, 1, 4, 5, 4])

# %%
array2=np.unique(array1,return_index=True,return_counts=True)
array2
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  array([0, 2, 8, 5, 3, 4]),
#  array([4, 4, 2, 3, 2, 2]))

# %%
array3=np.resize(array1,(3,2))
array3
# Out:
# array([[1, 1],
#        [2, 5],
#        [6, 4]])

# %% [markdown]
# Flatten Array

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
array3.flatten()
# Out:
# array([1, 1, 2, 5, 6, 4])

# %%
array3.flatten(order="F")
# Out:
# array([1, 2, 6, 1, 5, 4])

# %%
array4=np.array([[1,4,2,1],[4,2,3,2]])

# %%
print(np.ravel(array4))
# Out:
# [1 4 2 1 4 2 3 2]

# %%
print(np.ravel(array4,order="F"))
# Out:
# [1 4 4 2 2 3 1 2]

# %%
np.insert(array1,2,404)
# Out:
# array([  1,   1, 404,   2,   5,   6,   4,   2,   2,   3,   1,   2,   3,
#          6,   1,   4,   5,   4])

# %%
np.insert(array1,(4,5),432)
# Out:
# array([  1,   1,   2,   5, 432,   6, 432,   4,   2,   2,   3,   1,   2,
#          3,   6,   1,   4,   5,   4])

# %%
array3.resize((3,2))
array3
np.insert(array3,3,[22,22],axis=0)
# Out:
# array([[ 1,  1],
#        [ 2,  5],
#        [ 6,  4],
#        [22, 22]])

# %%
np.delete(array1,4)
# Out:
# array([1, 1, 2, 5, 4, 2, 2, 3, 1, 2, 3, 6, 1, 4, 5, 4])
