# %%
import pandas as pd

# %%
list1=[1,2,5,3,4,2,7,1]
dataframe1=pd.DataFrame(list1)
dataframe1.to_csv("test_csv.csv")

# %%
csv1=pd.read_csv("demo.csv")
csv1
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22958    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22959    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22960    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22961    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22962    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
csv2=pd.read_csv("demo.csv",usecols=[0,2,3])
csv2
# Out:
#       Series_reference  Data_value Suppressed
# 0          BDCQ.SEA1AA     80078.0        NaN
# 1          BDCQ.SEA1AA     78324.0        NaN
# 2          BDCQ.SEA1AA     85850.0        NaN
# 3          BDCQ.SEA1AA     90743.0        NaN
# 4          BDCQ.SEA1AA     81780.0        NaN
# ...                ...         ...        ...
# 22958    BDCQ.SEE3999A         NaN          Y
# 22959    BDCQ.SEE3999A         NaN          Y
# 22960    BDCQ.SEE3999A         NaN          Y
# 22961    BDCQ.SEE3999A         NaN          Y
# 22962    BDCQ.SEE3999A         NaN          Y
#
# [22963 rows x 3 columns]

# %%
csv3=pd.read_csv("demo.csv",skiprows=[0,2,3])
csv3
# Out:
#          BDCQ.SEA1AA  2011.06    80078 Unnamed: 3  F  Number  0  \
# 0        BDCQ.SEA1AA  2012.03  90743.0        NaN  F  Number  0
# 1        BDCQ.SEA1AA  2012.06  81780.0        NaN  F  Number  0
# 2        BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 3        BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# 4        BDCQ.SEA1AA  2013.03  91571.0        NaN  F  Number  0
# ...              ...      ...      ...        ... ..     ... ..
# 22955  BDCQ.SEE3999A  2017.06      NaN          Y  C  Number  0
# 22956  BDCQ.SEE3999A  2017.09      NaN          Y  C  Number  0
# 22957  BDCQ.SEE3999A  2017.12      NaN          Y  C  Number  0
# 22958  BDCQ.SEE3999A  2018.03      NaN          Y  C  Number  0
# 22959  BDCQ.SEE3999A  2018.06      NaN          Y  C  Number  0
#
#        Business Data Collection - BDC  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# ...

# %%
csv4=pd.read_csv("demo.csv",index_col="Series_reference")
csv4
# Out:
#                    Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# Series_reference
# BDCQ.SEA1AA       2011.06     80078.0        NaN      F  Number          0
# BDCQ.SEA1AA       2011.09     78324.0        NaN      F  Number          0
# BDCQ.SEA1AA       2011.12     85850.0        NaN      F  Number          0
# BDCQ.SEA1AA       2012.03     90743.0        NaN      F  Number          0
# BDCQ.SEA1AA       2012.06     81780.0        NaN      F  Number          0
# ...                   ...         ...        ...    ...     ...        ...
# BDCQ.SEE3999A     2017.06         NaN          Y      C  Number          0
# BDCQ.SEE3999A     2017.09         NaN          Y      C  Number          0
# BDCQ.SEE3999A     2017.12         NaN          Y      C  Number          0
# BDCQ.SEE3999A     2018.03         NaN          Y      C  Number          0
# BDCQ.SEE3999A     2018.06         NaN          Y      C  Number          0
#
# ...

# %%
csv5=pd.read_csv("demo.csv",header=5)
csv5
# Out:
#          BDCQ.SEA1AA  2012.06    81780 Unnamed: 3  F  Number  0  \
# 0        BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 1        BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# 2        BDCQ.SEA1AA  2013.03  91571.0        NaN  F  Number  0
# 3        BDCQ.SEA1AA  2013.06  81687.0        NaN  F  Number  0
# 4        BDCQ.SEA1AA  2013.09  81471.0        NaN  F  Number  0
# ...              ...      ...      ...        ... ..     ... ..
# 22953  BDCQ.SEE3999A  2017.06      NaN          Y  C  Number  0
# 22954  BDCQ.SEE3999A  2017.09      NaN          Y  C  Number  0
# 22955  BDCQ.SEE3999A  2017.12      NaN          Y  C  Number  0
# 22956  BDCQ.SEE3999A  2018.03      NaN          Y  C  Number  0
# 22957  BDCQ.SEE3999A  2018.06      NaN          Y  C  Number  0
#
#        Business Data Collection - BDC  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# ...

# %%
csv6=pd.read_csv("demo.csv",header=None , dtype={"Data_value":"float"})
csv6
# Out:
#                      0        1           2           3       4       5   \
# 0      Series_reference   Period  Data_value  Suppressed  STATUS   UNITS
# 1           BDCQ.SEA1AA  2011.06       80078         NaN       F  Number
# 2           BDCQ.SEA1AA  2011.09       78324         NaN       F  Number
# 3           BDCQ.SEA1AA  2011.12       85850         NaN       F  Number
# 4           BDCQ.SEA1AA  2012.03       90743         NaN       F  Number
# ...                 ...      ...         ...         ...     ...     ...
# 22959     BDCQ.SEE3999A  2017.06         NaN           Y       C  Number
# 22960     BDCQ.SEE3999A  2017.09         NaN           Y       C  Number
# 22961     BDCQ.SEE3999A  2017.12         NaN           Y       C  Number
# 22962     BDCQ.SEE3999A  2018.03         NaN           Y       C  Number
# 22963     BDCQ.SEE3999A  2018.06         NaN           Y       C  Number
#
#               6                               7   \
# ...

# %%
csv6.index
# Out:
# RangeIndex(start=0, stop=22964, step=1)

# %%
csv5.columns
# Out:
# Index(['BDCQ.SEA1AA', '2012.06', '81780', 'Unnamed: 3', 'F', 'Number', '0',
#        'Business Data Collection - BDC', 'Industry by employment variable',
#        'Filled jobs', 'Agriculture, Forestry and Fishing', 'Actual',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
csv5.describe
# Out:
# <bound method NDFrame.describe of          BDCQ.SEA1AA  2012.06    81780 Unnamed: 3  F  Number  0  \
# 0        BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 1        BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# 2        BDCQ.SEA1AA  2013.03  91571.0        NaN  F  Number  0
# 3        BDCQ.SEA1AA  2013.06  81687.0        NaN  F  Number  0
# 4        BDCQ.SEA1AA  2013.09  81471.0        NaN  F  Number  0
# ...              ...      ...      ...        ... ..     ... ..
# 22953  BDCQ.SEE3999A  2017.06      NaN          Y  C  Number  0
# 22954  BDCQ.SEE3999A  2017.09      NaN          Y  C  Number  0
# 22955  BDCQ.SEE3999A  2017.12      NaN          Y  C  Number  0
# 22956  BDCQ.SEE3999A  2018.03      NaN          Y  C  Number  0
# 22957  BDCQ.SEE3999A  2018.06      NaN          Y  C  Number  0
#
#        Business Data Collection - BDC  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# ...

# %%
csv6.head(2)
# Out:
#                  0        1           2           3       4       5   \
# 0  Series_reference   Period  Data_value  Suppressed  STATUS   UNITS
# 1       BDCQ.SEA1AA  2011.06       80078         NaN       F  Number
#
#           6                               7                                8   \
# 0  Magnitude                         Subject                            Group
# 1          0  Business Data Collection - BDC  Industry by employment variable
#
#                9                                  10              11  \
# 0  Series_title_1                     Series_title_2  Series_title_3
# 1     Filled jobs  Agriculture, Forestry and Fishing          Actual
#
#                12              13
# 0  Series_title_4  Series_title_5
# 1             NaN             NaN

# %%
csv6.tail(6)
# Out:
#                   0        1    2  3  4       5  6   \
# 22958  BDCQ.SEE3999A  2017.03  NaN  Y  C  Number  0
# 22959  BDCQ.SEE3999A  2017.06  NaN  Y  C  Number  0
# 22960  BDCQ.SEE3999A  2017.09  NaN  Y  C  Number  0
# 22961  BDCQ.SEE3999A  2017.12  NaN  Y  C  Number  0
# 22962  BDCQ.SEE3999A  2018.03  NaN  Y  C  Number  0
# 22963  BDCQ.SEE3999A  2018.06  NaN  Y  C  Number  0
#
#                                    7   \
# 22958  Business Data Collection - BDC
# 22959  Business Data Collection - BDC
# 22960  Business Data Collection - BDC
# 22961  Business Data Collection - BDC
# 22962  Business Data Collection - BDC
# 22963  Business Data Collection - BDC
#
#                                                  8   \
# 22958  Territorial authority by employment variable
# 22959  Territorial authority by employment variable
# 22960  Territorial authority by employment variable
# 22961  Territorial authority by employment variable
# 22962  Territorial authority by employment variable
# ...

# %%
csv6[2:10:2]
# Out:
#             0        1      2    3  4       5  6   \
# 2  BDCQ.SEA1AA  2011.09  78324  NaN  F  Number  0
# 4  BDCQ.SEA1AA  2012.03  90743  NaN  F  Number  0
# 6  BDCQ.SEA1AA  2012.09  79261  NaN  F  Number  0
# 8  BDCQ.SEA1AA  2013.03  91571  NaN  F  Number  0
#
#                                7                                8   \
# 2  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
# 6  Business Data Collection - BDC  Industry by employment variable
# 8  Business Data Collection - BDC  Industry by employment variable
#
#             9                                  10      11   12   13
# 2  Filled jobs  Agriculture, Forestry and Fishing  Actual  NaN  NaN
# 4  Filled jobs  Agriculture, Forestry and Fishing  Actual  NaN  NaN
# 6  Filled jobs  Agriculture, Forestry and Fishing  Actual  NaN  NaN
# 8  Filled jobs  Agriculture, Forestry and Fishing  Actual  NaN  NaN

# %%
csv6.to_numpy()
# Out:
# array([['Series_reference', 'Period', 'Data_value', ...,
#         'Series_title_3', 'Series_title_4', 'Series_title_5'],
#        ['BDCQ.SEA1AA', '2011.06', '80078', ..., 'Actual', nan, nan],
#        ['BDCQ.SEA1AA', '2011.09', '78324', ..., 'Actual', nan, nan],
#        ...,
#        ['BDCQ.SEE3999A', '2017.12', nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', '2018.03', nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', '2018.06', nan, ..., 'Actual', nan, nan]],
#       dtype=object)

# %% [markdown]
# or

# %%
import numpy as np
array1=np.asarray(csv6)
array1
# Out:
# array([['Series_reference', 'Period', 'Data_value', ...,
#         'Series_title_3', 'Series_title_4', 'Series_title_5'],
#        ['BDCQ.SEA1AA', '2011.06', '80078', ..., 'Actual', nan, nan],
#        ['BDCQ.SEA1AA', '2011.09', '78324', ..., 'Actual', nan, nan],
#        ...,
#        ['BDCQ.SEE3999A', '2017.12', nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', '2018.03', nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', '2018.06', nan, ..., 'Actual', nan, nan]],
#       dtype=object)

# %%
csv6.sort_index(axis=0,ascending=False)
# Out:
#                      0        1           2           3       4       5   \
# 22963     BDCQ.SEE3999A  2018.06         NaN           Y       C  Number
# 22962     BDCQ.SEE3999A  2018.03         NaN           Y       C  Number
# 22961     BDCQ.SEE3999A  2017.12         NaN           Y       C  Number
# 22960     BDCQ.SEE3999A  2017.09         NaN           Y       C  Number
# 22959     BDCQ.SEE3999A  2017.06         NaN           Y       C  Number
# ...                 ...      ...         ...         ...     ...     ...
# 4           BDCQ.SEA1AA  2012.03       90743         NaN       F  Number
# 3           BDCQ.SEA1AA  2011.12       85850         NaN       F  Number
# 2           BDCQ.SEA1AA  2011.09       78324         NaN       F  Number
# 1           BDCQ.SEA1AA  2011.06       80078         NaN       F  Number
# 0      Series_reference   Period  Data_value  Suppressed  STATUS   UNITS
#
#               6                               7   \
# ...

# %%
csv6[0][0]="sky"
csv6
# Out:
# C:\Users\rajki\AppData\Local\Temp\ipykernel_16256\4201803344.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   csv6[0][0]="sky"
#                   0        1           2           3       4       5   \
# ...

# %%
csv6.loc[0][1]="shashi kant"
csv6
# Out:
# C:\Users\rajki\AppData\Local\Temp\ipykernel_16256\2588242787.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   csv6.loc[0][1]="shashi kant"
#                   0            1           2           3       4       5   \
# ...

# %%
csv6.loc[0,0]
# Out:
# 'sky'

# %%
csv6.iloc[1,2]
# Out:
# '80078'

# %%
csv6.drop(5,axis=1)
# Out:
#                   0            1           2           3       4          6   \
# 0                sky  shashi kant  Data_value  Suppressed  STATUS  Magnitude
# 1        BDCQ.SEA1AA      2011.06       80078         NaN       F          0
# 2        BDCQ.SEA1AA      2011.09       78324         NaN       F          0
# 3        BDCQ.SEA1AA      2011.12       85850         NaN       F          0
# 4        BDCQ.SEA1AA      2012.03       90743         NaN       F          0
# ...              ...          ...         ...         ...     ...        ...
# 22959  BDCQ.SEE3999A      2017.06         NaN           Y       C          0
# 22960  BDCQ.SEE3999A      2017.09         NaN           Y       C          0
# 22961  BDCQ.SEE3999A      2017.12         NaN           Y       C          0
# 22962  BDCQ.SEE3999A      2018.03         NaN           Y       C          0
# 22963  BDCQ.SEE3999A      2018.06         NaN           Y       C          0
#
#                                    7   \
# ...
