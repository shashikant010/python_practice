# %%
import pandas as pd

# %%
csv1=pd.read_csv("demo2.csv")
csv1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv1.dropna()
# Out:
#     Index      Customer Id First Name Last Name                       Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 2       3  6F94879bDAfE5a6        Roy     Berry                 Murillo-Perry
# 4       5  053d585Ab6b3159     Joanna    Bender      Martin, Lang and Andrade
# 5       6  2d08FB17EE273F4      Aimee     Downs                  Steele Group
# 6       7  EA4d384DfDbBf77     Darren      Peck  Lester, Woodard and Mitchell
# ..    ...              ...        ...       ...                           ...
# 95     96  cb8E23e48d22Eae       Karl     Greer                     Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson         Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                 Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer            Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes            Le, Nash and Cross
#
# ...

# %%
csv1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %% [markdown]
# We can add axis parameter in dropna method : axis=0 remove data in row and axix=1 removes data in column

# %% [markdown]
# in dropna how="any" will drops all rows with na  and how="all" will remove only that row which has all null value

# %% [markdown]
# in dropna subset=["columnName","columnName"] can be used to detect and remove null values along that particular column

# %% [markdown]
# inplace=True can be use to inplace the value to other variable

# %% [markdown]
# thresh=count will drop the column with count number of null values other wise will not drop it

# %%
csv1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv1.fillna({"City":"NO CITY","Phone 2":"NO PHONE"})
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan            NO CITY
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %% [markdown]
# csv1.fillna(method="ffill") : will fill the null with next non-null value available

# %% [markdown]
# method="bfill" fills the backward value

# %% [markdown]
# axis=0 will fill according to row and axis=1 will fill according to column

# %% [markdown]
# limit = count will fill only count number of null values in a single row
