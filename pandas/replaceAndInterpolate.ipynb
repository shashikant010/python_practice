# %%
import pandas as pd

# %%
csv1=pd.read_csv("demo2.csv")
csv1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv1.replace(to_replace="Chile",value="sky")
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv1.replace(to_replace=["Karl","Lynn","Fred"],value=["sky1","sky2","sky3"])
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       sky1     Greer
# 96     97  CeD220bdAaCfaDf       sky2  Atkinson
# 97     98  28CDbC0dFe4b1Db       sky3    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan                NaN
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv1.replace({"First Name":"[A-Za-z]"},"hello",regex=True)
# Out:
#     Index      Customer Id                                First Name  \
# 0       1  DD37Cf93aecA6Dc            hellohellohellohellohellohello
# 1       2  1Ef7b82A4CAAD10       hellohellohellohellohellohellohello
# 2       3  6F94879bDAfE5a6                           hellohellohello
# 3       4  5Cef8BFA16c5e3c                 hellohellohellohellohello
# 4       5  053d585Ab6b3159            hellohellohellohellohellohello
# ..    ...              ...                                       ...
# 95     96  cb8E23e48d22Eae                      hellohellohellohello
# 96     97  CeD220bdAaCfaDf                      hellohellohellohello
# 97     98  28CDbC0dFe4b1Db                      hellohellohellohello
# 98     99  c23d1D9EE8DEB0A            hellohellohellohellohellohello
# 99    100  2354a0E336A91A1  hellohellohellohellohellohellohellohello
#
#    Last Name                          Company               City  \
# 0     Baxter                  Rasmussen Group       East Leonard
# ...

# %%
csv1.replace("Chile",method="ffill")
# Out:
# C:\Users\rajki\AppData\Local\Temp\ipykernel_16208\981311865.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace("Chile",method="ffill")
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# ...

# %% [markdown]
# similarly we can also use limit in replace method

# %% [markdown]
# Interpolate function replace automatically fills the number null data

# %%
csv1.interpolate()
# Out:
# C:\Users\rajki\AppData\Local\Temp\ipykernel_16208\966396185.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   csv1.interpolate()
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       NaN
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# csv.interpolate(method="method name") linear is default

# %% [markdown]
# similarly you can also give axis and limit in the interpolate function

# %% [markdown]
# we can also give limit_direction="forward" or "backward" pr "both"

# %% [markdown]
# limit_area="inside" will fill all null values and "outside will not"

# %% [markdown]
# implace = True will make change in the original data and False will make a copy of data
